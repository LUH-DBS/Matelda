# %%
import pickle

# %%
with open('/Users/fatemehahmadi/Documents/StateOfTheArt/santos/hashmap/tus_main_triple_index.pickle', 'rb') as f:
    yago_type_score = pickle.load(f)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import networkx.algorithms.community as nx_comm

# Load the graph from the file
G = nx.read_gpickle('/Users/fatemehahmadi/Documents/StateOfTheArt/santos/stats/graph.gpickle')

# comp = nx.algorithms.community.girvan_newman(G)

# # Print the partitions
# for c in next(comp):
#     print(c)

# Visualize the graph
nx.draw(G, with_labels=True)
plt.show()

nx_comm.louvain_communities(G)
# Out:
# [{'169.csv'},
#  {'1.csv',
#   '105.csv',
#   '117.csv',
#   '125.csv',
#   '126.csv',
#   '141.csv',
#   '142.csv',
#   '144.csv',
#   '153.csv',
#   '164.csv',
#   '171.csv',
#   '18.csv',
#   '20.csv',
#   '24.csv',
#   '25.csv',
#   '35.csv',
#   '41.csv',
#   '59.csv',
#   '6.csv',
#   '63.csv',
#   '77.csv',
#   '8.csv',
#   '97.csv'},
#  {'10.csv',
#   '116.csv',
#   '12.csv',
#   '122.csv',
#   '129.csv',
#   '133.csv',
#   '135.csv',
#   '136.csv',
#   '139.csv',
#   '140.csv',
#   '15.csv',
#   '16.csv',
#   '174.csv',
#   '21.csv',
#   '3.csv',
#   '31.csv',
#   '32.csv',
#   '33.csv',
#   '37.csv',
#   '38.csv',
#   '4.csv',
#   '43.csv',
#   '44.csv',
#   '53.csv',
#   '55.csv',
#   '68.csv',
#   '76.csv',
#   '78.csv',
#   '82.csv',
#   '87.csv',
#   '90.csv',
#   '92.csv',
#   '93.csv'},
#  {'106.csv',
#   '108.csv',
#   '115.csv',
#   '143.csv',
#   '155.csv',
#   '161.csv',
#   '172.csv',
#   '34.csv',
#   '46.csv',
#   '57.csv',
#   '85.csv',
#   '86.csv',
# ...

# %%
import pandas as pd

# %%
path = '/Users/fatemehahmadi/Documents/StateOfTheArt/santos/benchmark/tus_benchmark/datalake/mov_dataworld.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    movieid                       title mpaa_rating    budget      gross  \
# 0        1          Look Who's Talking       PG-13   7500000  296000000
# 1        2          Driving Miss Daisy          PG   7500000  145793296
# 2        3              Turner & Hooch          PG  13000000   71079915
# 3        4  Born on the Fourth of July           R  14000000  161001698
# 4        5             Field of Dreams          PG  15000000   84431625
#
#   release_date    genre  runtime  rating  rating_count  \
# 0   1989-10-12  Romance       93     5.9       73638.0
# 1   1989-12-13   Comedy       99     7.4       91075.0
# 2   1989-07-28    Crime      100     7.2       91415.0
# 3   1989-12-20      War      145     7.2       91415.0
# 4   1989-04-21    Drama      107     7.5      101702.0
#
#                                              summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
df.drop(['summary'], axis=1, inplace=True)

# %%
df
# Out:
#      movieid                        title mpaa_rating     budget      gross  \
# 0          1           Look Who's Talking       PG-13    7500000  296000000
# 1          2           Driving Miss Daisy          PG    7500000  145793296
# 2          3               Turner & Hooch          PG   13000000   71079915
# 3          4   Born on the Fourth of July           R   14000000  161001698
# 4          5              Field of Dreams          PG   15000000   84431625
# ..       ...                          ...         ...        ...        ...
# 629      631                      Encanto          PG  150000000  226163416
# 630      632                         Dune       PG-13  165000000  400195457
# 631      633               No Time to Die       PG-13  250000000  765199095
# 632      634             tick, tick…BOOM!       PG-13   55000000     106457
# 633      635  Venom: Let There Be Carnage       PG-13  110000000  212500000
#
#     release_date    genre  runtime  rating  rating_count
# ...

# %%
df.to_csv(path, index=False)

# %%
import pandas as pd

# create a sample data frame
df = pd.DataFrame({'col1': ['hello', 'world'], 'col2': ['foo', 'bar']})

# convert the data frame to a string
df_str = df.to_string()

# create a set of unique characters
char_set = set(df_str)

# print the set of characters
print(char_set)
# Out:
# {'w', '1', 'o', 'e', 'r', 'c', 'f', 'a', 'l', ' ', 'd', '\n', '2', '0', 'b', 'h'}
