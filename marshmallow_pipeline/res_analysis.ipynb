# %%
import pickle
import os 

results_path = "/Users/fatemehahmadi/Documents/Github-Private/ED-Scale/marshmallow_pipeline/output/results"
all_col_clusters_scores = []
for f in os.listdir(results_path):
    if f.startswith('scores_col_cluster_'):
        scores = pickle.load(open(os.path.join(results_path, f), 'rb'))
        all_col_clusters_scores.append(scores)

# %%
import pandas as pd
df = pd.DataFrame.from_dict(all_col_clusters_scores)
print(df['tp'].sum()/(df['tp'].sum() + df['fp'].sum()))
ae = ("Actual Errors:", df['tp'].sum() + df['fn'].sum())
tt = ("All values:", df['tp'].sum() + df['fn'].sum() + df['fp'].sum() + df['tn'].sum())
ae / tt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame.from_dict(all_col_clusters_scores)
#       3 print(df['tp'].sum()/(df['tp'].sum() + df['fp'].sum()))
#       4 ae = ("Actual Errors:", df['tp'].sum() + df['fn'].sum())
#
# NameError: name 'all_col_clusters_scores' is not defined

# %%
all_col_clusters_scores_df = pd.DataFrame.from_dict(all_col_clusters_scores)

# %%
all_col_clusters_scores_df
# Out:
#    col_cluster  precision    recall   f_score support    tp      fp   fn  \
# 0       (3, 2)   0.019007  0.019007  0.019007    None  6650  343269    0
# 1       (3, 3)   0.988693  0.988693  0.988693    None     0       0   97
# 2       (0, 2)   0.503233  0.503233  0.503233    None    23     922    0
# 3       (0, 3)   1.000000  1.000000  1.000000    None     0       0    0
# 4       (2, 1)   0.986364  0.986364  0.986364    None    82      15    0
# 5       (2, 0)   1.000000  1.000000  1.000000    None     0       0    0
# 6       (1, 1)   0.972264  0.972264  0.972264    None     0       0  129
# 7       (1, 0)   1.000000  1.000000  1.000000    None     0       0    0
# 8       (3, 4)   0.981113  0.981113  0.981113    None     0       0  168
# 9       (0, 1)   0.983477  0.983477  0.983477    None     0       0   46
# 10      (0, 0)   1.000000  1.000000  1.000000    None     0       0    0
# 11      (1, 4)   0.885353  0.885353  0.885353    None    29     213   50
# 12      (3, 1)   1.000000  1.000000  1.000000    None     0       0    0
# 13      (3, 0)   1.000000  1.000000  1.000000    None     0       0    0
# 14      (1, 2)   1.000000  1.000000  1.000000    None     0       0    0
# 15      (1, 3)   1.000000  1.000000  1.000000    None     0       0    0
# 16      (2, 2)   1.000000  1.000000  1.000000    None     0       0    0
# 17      (2, 3)   0.950000  0.950000  0.950000    None     0       0   55
#
#        tn
# 0       1
# 1    8482
# 2     911
# 3     928
# 4    1003
# 5     550
# 6    4522
# 7     368
# 8    8727
# 9    2738
# 10   2320
# 11   2002
# 12  34992
# 13  34992
# 14   2294
# 15    242
# 16   1100
# 17   1045

# %%
import pickle 

with open("/Users/fatemehahmadi/Documents/Github-Private/ED-Scale/marshmallow_pipeline/output/results/scores_all.pickle", 'rb') as f:
    t = pickle.load(f)
t
# Out:
# {'n_samples': 94,
#  'total_recall': 0.9256378769272752,
#  'total_precision': 0.01931646369763356,
#  'total_fscore': 0.03784320506956143,
#  'total_tp': 6784,
#  'total_fp': 344419,
#  'total_tn': 107217,
#  'total_fn': 545}

# %%
import pandas as pd
import json
import os

repition = range(3, 4)
labeling_budgets = range(1, 2)
sandbox_path = "/home/fatemeh/ED-Scale/Old_Files/Benchmarks/kaggle_sample_dataset/separated_kaggle_lake"
results_path = "/home/fatemeh/ED-Scale/Old_Files/Benchmarks/kaggle_sample_dataset/results"
dir_levels = 1 # That means we have files in each subdirectory of sandbox dir
datasets = ["best_sellers", "1", "2", "cou_1", "cou_2", "disney", "imdb", "marvels"]
algorithm = 'raha'


if dir_levels == 1:
    for dir in os.listdir(sandbox_path):
        datasets.append(dir)

# "actuall_errors_json":[]

results_dict = {"algorithm":[], "dataset":[], "execution_number":[], 
              "precision": [], "recall": [], "f_score": [],
                "tp": [], "ed_tpfp": [], "ed_tpfn": [], "execution_time": [],
                 "number_of_labeled_tuples": [], "number_of_labeled_cells": [], "detected_errors_keys":[]}
count = 0 
d = []
no_errors_files = []
raha_erros_file = []
for i in repition:
    for dataset in datasets:
        if dataset not in no_errors_files and dataset not in raha_erros_file:
            for label_budget in labeling_budgets:
                # "/{}_labels_{}_execution".format(label_budget, i) +
                file_path = results_path + '/{}_{}_number#{}_${}$labels.json'\
                            .format(algorithm, dataset, str(i), str(label_budget))
                # print(file_path)
                if os.path.exists(file_path):
                   
                    with open(file_path) as file:
                        json_content = json.load(file)
                        results_dict['algorithm'].append(algorithm)
                        results_dict['dataset'].append(dataset)
                        # results_dict['dataset_shape'].append(json_content['dataset_shape'])
                        results_dict['execution_number'].append(i)
                        results_dict['precision'].append(json_content['precision'])
                        results_dict['recall'].append(json_content['recall'])
                        results_dict['f_score'].append(json_content['f_score'])
                        results_dict['tp'].append(json_content['tp'])
                        results_dict['ed_tpfp'].append(json_content['ed_tpfp'])
                        results_dict['ed_tpfn'].append(json_content['ed_tpfn'])
                        results_dict['execution_time'].append(json_content['execution-time'])
                        results_dict['number_of_labeled_tuples'].append(json_content['number_of_labeled_tuples'])
                        results_dict['number_of_labeled_cells'].append(json_content['number_of_labeled_cells'])
                        # results_dict['actuall_errors_json'].append(json_content['actuall_errors_json'])
                        results_dict['detected_errors_keys'].append(json_content['detected_errors_keys'])
                else:
                    print("The file does not exist: {}".format(file_path))
                    print()
        
result_df = pd.DataFrame.from_dict(results_dict)
# result_df.to_csv("/Users/fatemehahmadi/Documents/Github-Private/ED-Scale/marshmallow_pipeline/kaggle_raha/raha-dtype-orig/results_all_{}.csv".format(algorithm))
# Out:
# The file does not exist: /home/fatemeh/ED-Scale/Old_Files/Benchmarks/kaggle_sample_dataset/results/raha_kaggle_sample_sandbox_number#3_$1$labels.json

# %%
result_df
# Out:
#   algorithm       dataset  execution_number  precision    recall   f_score  \
# 0      raha  best_sellers                 3   0.000000  0.000000  0.000000
# 1      raha             1                 3   0.000000  0.000000  0.000000
# 2      raha             2                 3   0.000000  0.000000  0.000000
# 3      raha         cou_1                 3   0.954545  0.604712  0.740385
# 4      raha         cou_2                 3   0.540037  0.489039  0.513274
# 5      raha        disney                 3   0.000000  0.000000  0.000000
# 6      raha          imdb                 3   0.000000  0.000000  0.000000
# 7      raha       marvels                 3   0.000000  0.000000  0.000000
#
#       tp  ed_tpfp  ed_tpfn  execution_time  number_of_labeled_tuples  \
# 0    0.0      0.0      178        1.521071                         1
# 1    0.0      0.0       90        1.334939                         1
# 2    0.0      0.0      115        4.698917                         1
# 3  231.0    242.0      382        1.732462                         1
# 4  290.0    537.0      593        2.518604                         1
# 5    0.0      0.0      122        1.321739                         1
# 6    0.0      0.0      247        6.650847                         1
# 7    0.0      0.0    10070      764.969854                         1
#
#    number_of_labeled_cells                               detected_errors_keys
# 0                        7                                                 []
# 1                        8                                                 []
# 2                       17                                                 []
# 3                       13  [[0, 4], [1, 4], [2, 4], [3, 4], [4, 4], [5, 4...
# 4                       21  [[0, 10], [1, 10], [2, 10], [3, 10], [4, 10], ...
# 5                        6                                                 []
# 6                       14                                                 []
# 7                       12                                                 []

# %%
pp, rr, ff = 0, 0, 0
for i in range(1, 4):
    df = result_df[result_df['execution_number'] == i]
    p = sum(df['tp'])/(sum(df['ed_tpfp']))
    r = sum(df['tp'])/(sum(df['ed_tpfn']))
    f_score = 2*p*r/(p+r)
    print(df["number_of_labeled_cells"].sum())
    pp += p
    rr += r
    ff += f_score
print(pp/3, rr/3, ff/3)
# Out:
# 98
# 98
# 98
# 0.5315882897370388 0.33663456503426453 0.3391296236219506

# %%
print(p, r, f_score)
# Out:
# 0.18012992165030248 0.49620927532272385 0.26431157113492076

# %%
result_df[result_df["execution_number"]== 1]["number_of_labeled_cells"].sum()

# %%
import pickle
import pandas as pd 

path = "/Users/fatemehahmadi/Documents/Github-Private/ED-Scale/marshmallow_pipeline/mediate_files/col_grouping_res/col_df_res/col_df_labels_cluster_3.pickle"

with open(path, 'rb') as f:
    t = pickle.load(f)
    df = pd.DataFrame.from_dict(t)

# %%
df["table_path"].unique()

# %%
df[df["column_cluster_label"] == 2]
# Out:
#     column_cluster_label                                          col_value  \
# 2                      2  [A Year of Marvels: April Infinite Comic (2016...
# 3                      2  [(2016), (2016), (2016), (2016), (2016), (2016...
# 4                      2  [A Year of Marvels: April Infinite Comic (2016...
# 5                      2  [Yves Bigerel, Jamal Campbell, Danilo S. Beyru...
# 6                      2  [Yves Bigerel, Chris Sims, Chad Bowers, Ryan N...
# 7                      2  [Jamal Campbell, None, None, Jamal Campbell, J...
# 8                      2  [Marvel Universe, Marvel Universe, Marvel Univ...
# 9                      2  [Infinite Comic, Infinite Comic, Infinite Comi...
# 10                     2  [Rated T+, None, Rated T+, None, None, None, N...
# 11                     2  [Free, Free, Free, Free, Free, Free, Free, Fre...
#
#                             table_id  \
# 2   6b4b915850836047cbb546c20c7442d3
# 3   6b4b915850836047cbb546c20c7442d3
# 4   6b4b915850836047cbb546c20c7442d3
# 5   6b4b915850836047cbb546c20c7442d3
# 6   6b4b915850836047cbb546c20c7442d3
# 7   6b4b915850836047cbb546c20c7442d3
# 8   6b4b915850836047cbb546c20c7442d3
# 9   6b4b915850836047cbb546c20c7442d3
# 10  6b4b915850836047cbb546c20c7442d3
# 11  6b4b915850836047cbb546c20c7442d3
#
#                                            table_path  table_cluster  col_id
# 2   /Users/fatemehahmadi/Documents/Github-Private/...              3       0
# 3   /Users/fatemehahmadi/Documents/Github-Private/...              3       1
# 4   /Users/fatemehahmadi/Documents/Github-Private/...              3       2
# 5   /Users/fatemehahmadi/Documents/Github-Private/...              3       5
# 6   /Users/fatemehahmadi/Documents/Github-Private/...              3       6
# 7   /Users/fatemehahmadi/Documents/Github-Private/...              3       7
# 8   /Users/fatemehahmadi/Documents/Github-Private/...              3       8
# 9   /Users/fatemehahmadi/Documents/Github-Private/...              3       9
# 10  /Users/fatemehahmadi/Documents/Github-Private/...              3      10
# 11  /Users/fatemehahmadi/Documents/Github-Private/...              3      11

# %%
import pickle
import random
import pandas as pd 

for i in range(4):
    print("********Table Group {}********".format(i))
    path = "/Users/fatemehahmadi/Documents/Github-Private/ED-Scale/marshmallow_pipeline/mediate_files/col_grouping_res/col_df_res/col_df_labels_cluster_{}.pickle".format(i)
    with open(path, 'rb') as f:
        t = pickle.load(f)
        df = pd.DataFrame.from_dict(t)
        for j in range(df["column_cluster_label"].unique().shape[0]):
            print("---------Column Group {}--------".format(j))
            col_values = df[df["column_cluster_label"] == j]["col_value"].to_list()
            for cv in col_values:
                print(random.sample(cv, 5))

# %%
import os
import pandas as pd
import html
import re

def value_normalizer(value):
    """
    This method takes a value and minimally normalizes it.
    """
    if isinstance(value, str):
        value = html.unescape(value)
        value = re.sub("[\t\n ]+", " ", value, re.UNICODE)
        value = value.strip("\t\n ")
    return value

def read_csv_dataset(dataset_path):
    """
    This method reads a dataset from a csv file path.
    """
    dataframe = pd.read_csv(dataset_path, sep=",", header="infer", encoding="utf-8", dtype=str,
                                keep_default_na=False, low_memory=False).applymap(value_normalizer)
    dataframe = dataframe.replace('', 'NULL')
    dataframe = dataframe.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)
    return dataframe

path = "/home/fatemeh/ED-Scale/Old_Files/Benchmarks/kaggle_sample_dataset/separated_kaggle_lake/kaggle_sample_sandbox/best_sellers"

clean_df_path = os.path.join(path, "clean.csv")
dirty_df_path = os.path.join(path, "dirty_clean.csv")

clean_df = read_csv_dataset(clean_df_path)
dirty_df = read_csv_dataset(dirty_df_path)

# clean_df = pd.read_csv(clean_df_path)
# clean_df = clean_df.astype({'place':'int'})
# clean_df.to_csv(clean_df_path, index=False)
dirty_df != clean_df
# Out:
#       Name  Author  User Rating  Reviews  Price   Year  Genre
# 0    False   False        False    False  False  False  False
# 1    False   False        False    False  False  False  False
# 2    False   False        False    False  False  False  False
# 3    False   False        False    False  False  False  False
# 4    False   False        False    False  False  False  False
# ..     ...     ...          ...      ...    ...    ...    ...
# 545  False   False        False    False  False  False  False
# 546  False   False        False    False  False  False  False
# 547  False   False        False    False  False  False  False
# 548  False   False        False    False  False  False  False
# 549  False   False        False    False  False  False  False
#
# [550 rows x 7 columns]

# %%
dirty_df = dirty_df.astype({'Length':'float'})
dirty_df
# Out:
#     Details     Accession          Release_Date  \
# 0      NULL  YP_009724389  2020-01-13T00:00:00Z
# 1      NULL  YP_009725255  2020-01-17T00:00:00Z
# 2      NULL  YP_009725295  2020-01-28T00:00:00Z
# 3      NULL  YP_009725296  2020-01-28T00:00:00Z
# 4      NULL  YP_009724390  2020-01-13T00:00:00Z
# ..      ...           ...                   ...
# 459    NULL      QHU36838  2020-02-05T00:00:00Z
# 460    NULL      QHU36839  2020-02-05T00:00:00Z
# 461    NULL      QHU36840  2020-02-05T00:00:00Z
# 462    NULL      QHU36841  2020-02-05T00:00:00Z
# 463    NULL      QHU36842  2020-02-05T00:00:00Z
#
#                                                Species            Genus  \
# 0    Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 1    Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 2    Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 3    Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 4    Severe acute respiratory syndrome-related coro...  Betacoronavirus
# ..                                                 ...              ...
# 459  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 460  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 461  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 462  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 463  Severe acute respiratory syndrome-related coro...  Betacoronavirus
#
#             Family  Length Genotype Genome_Region Segment  \
# 0    Coronaviridae    7096     NULL          NULL    NULL
# 1    Coronaviridae      38     NULL          NULL    NULL
# 2    Coronaviridae    4405     NULL          NULL    NULL
# 3    Coronaviridae      43     NULL          NULL    NULL
# 4    Coronaviridae    1273     NULL          NULL    NULL
# ..             ...     ...      ...           ...     ...
# 459  Coronaviridae      61     NULL          NULL    NULL
# 460  Coronaviridae     121     NULL          NULL    NULL
# 461  Coronaviridae     121     NULL          NULL    NULL
# 462  Coronaviridae     419     NULL          NULL    NULL
# 463  Coronaviridae      38     NULL          NULL    NULL
#
#                          Protein Geo_Location          Host Isolation_Source  \
# 0             orf1ab polyprotein         NULL  Homo sapiens             NULL
# 1                  ORF10 protein        China  Homo sapiens             NULL
# 2              orf1a polyprotein        China  Homo sapiens             NULL
# 3                          ORF7b        China  Homo sapiens             NULL
# 4           surface glycoprotein        China  Homo sapiens             NULL
# ..                           ...          ...           ...              ...
# 459                 ORF6 protein        China  Homo sapiens             lung
# 460                ORF7a protein        China  Homo sapiens             lung
# 461                 ORF8 protein        China  Homo sapiens             lung
# 462  nucleocapsid phosphoprotein        China  Homo sapiens             lung
# 463                ORF10 protein        China  Homo sapiens             lung
#
#     Collection_Date BioSample  \
# 0           2019-12      NULL
# 1           2019-12      NULL
# 2           2019-12      NULL
# 3           2019-12      NULL
# 4           2019-12      NULL
# ..              ...       ...
# 459      2019-12-30      NULL
# 460      2019-12-30      NULL
# 461      2019-12-30      NULL
# 462      2019-12-30      NULL
# 463      2019-12-30      NULL
#
#                                          GenBank_Title
# 0    orf1ab polyprotein [Wuhan seafood market pneum...
# 1    ORF10 protein [Wuhan seafood market pneumonia ...
# 2    orf1a polyprotein [Wuhan seafood market pneumo...
# 3         ORF7b [Wuhan seafood market pneumonia virus]
# 4    surface glycoprotein [Wuhan seafood market pne...
# ..                                                 ...
# 459  ORF6 protein [Severe acute respiratory syndrom...
# 460  ORF7a protein [Severe acute respiratory syndro...
# 461  ORF8 protein [Severe acute respiratory syndrom...
# 462  nucleocapsid phosphoprotein [Severe acute resp...
# 463  ORF10 protein [Severe acute respiratory syndro...
#
# [464 rows x 17 columns]

# %%
dirty_df.head(2)
# Out:
#    Details     Accession          Release_Date  \
# 0      NaN  YP_009724389  2020-01-13T00:00:00Z
# 1      NaN  YP_009725255  2020-01-17T00:00:00Z
#
#                                              Species            Genus  \
# 0  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 1  Severe acute respiratory syndrome-related coro...  Betacoronavirus
#
#           Family  Length  Genotype  Genome_Region  Segment  \
# 0  Coronaviridae  7096.0       NaN            NaN      NaN
# 1  Coronaviridae    38.0       NaN            NaN      NaN
#
#               Protein Geo_Location          Host Isolation_Source  \
# 0  orf1ab polyprotein          NaN  Homo sapiens              NaN
# 1       ORF10 protein        China  Homo sapiens              NaN
#
#   Collection_Date  BioSample  \
# 0         2019-12        NaN
# 1         2019-12        NaN
#
#                                        GenBank_Title
# 0  orf1ab polyprotein [Wuhan seafood market pneum...
# 1  ORF10 protein [Wuhan seafood market pneumonia ...
